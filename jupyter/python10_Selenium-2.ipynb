# %%
# !dir

# %%
# !pip install selenium

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

# %%
from bs4 import BeautifulSoup as bs
from hdfs import InsecureClient
import pandas as pd
import folium
from datetime import datetime

# %%
# Chrome 옵션 설정
options = Options()
options.binary_location = '/usr/local/bin/chrome-headless-shell' # 크롬 브라우저 경로
# options.add_argument('--headless')
options.add_argument('--no-sandbox') # 실행 가드? 해제
options.add_argument('--disable-dev-shm-usage') # 공유 메모리 비활성화
options.add_argument('--disable-gpu') # GPU 비활성화
options.add_argument('--window-size=1920,1080') # 가상 화면크기 설정
# ChromeDriver 설정
# service = Service('/usr/local/bin/chromedriver')
service = webdriver.ChromeService() # executable_path='/usr/local/bin/chromedriver'
driver = webdriver.Chrome(service=service, options=options)

# %%
driver.get('https://www.starbucks.co.kr/index.do')
print(driver.title)

hover_el = driver.find_element(By.CSS_SELECTOR, '#gnb > div > nav > div > ul > li.gnb_nav03 > h2 > a')
menu_opt = driver.find_element(By.CSS_SELECTOR, '#gnb > div > nav > div > ul > li.gnb_nav03 > div > div > div > ul:nth-child(1) > li.gnb_sub_ttl > a')

# 마우스 호버 액션
time.sleep(3)
actions = ActionChains(driver)
actions.move_to_element(hover_el).perform() # perform == run
print('[[호버 동작]]')
# 대기시간
time.sleep(1.5)
print('[[매장메뉴 선택]]')
menu_opt.click()

print('[[페이지 이동 중]]')
time.sleep(6.5)
driver.find_element(By.CSS_SELECTOR, '.loca_search > h3 > a').click()
time.sleep(0.5)
driver.find_element(By.CSS_SELECTOR, '.sido_arae_box > li:nth-child(6) > a').click()
time.sleep(0.5)
driver.find_element(By.CSS_SELECTOR, '.gugun_arae_box > li:nth-child(1) > a').click()
# Out:
# Starbucks Korea
# [[호버 동작]]
# [[매장메뉴 선택]]
# [[페이지 이동 중]]

# %%
# 현재 페이지 정보 가져오기
star_list = []
html = driver.page_source
soup = bs(html, 'html.parser')
contents = soup.select_one('.quickSearchResultBoxSidoGugun')
listnames = contents.select('li')
for listname in listnames:
    star_list.append([listname['data-name'], listname['data-lat'], listname['data-long'], listname.select_one('p').text, listname.select_one('i')['class'][0]])

driver.quit()

# %%
columns = ['name', 'lat', 'lon', 'addr', 'stype']
starbucks = pd.DataFrame(star_list, columns=columns)

# %%
starbucks.head(10)
# Out:
#       name                 lat                 lon  \
# 0  금정남산동DT    35.2621786292157    129.091325043351
# 1   금정구청DT    35.2388135211636    129.092985849499
# 2   온천장역DT           35.224006           129.08656
# 3    부산대정문   35.23212165114605   129.0844959292725
# 4     부산대역   35.23052180284867  129.08869433543111
# 5    금정이마트  35.249819818853915  129.09078227309334
# 6     금정구서  35.246908383445785  129.08873844189125
# 7     부산서동   35.21463924851766  129.10558442984572
# 8  용호동W스퀘어          35.1337011          129.113324
# 9    동명대DT   35.12311959047579  129.09901642703608
#
#                                                 addr          stype
# 0                 부산광역시 금정구 중앙대로 1989 (남산동)1522-3232  pin_generalDT
# 1                 부산광역시 금정구 중앙대로 1730 (부곡동)1522-3232  pin_generalDT
# 2                   부산광역시 금정구 식물원로 13 (장전동)1522-3232  pin_generalDT
# 3              부산광역시 금정구 부산대학로64번길 12 (장전동)1522-3232    pin_general
# 4          부산광역시 금정구 장전로12번길 64, 1~4층 (장전동)1522-3232    pin_general
# 5             부산광역시 금정구 중앙대로1841번길 24 (구서동)1522-3232    pin_general
# 6                   부산광역시 금정구 금강로 441 (구서동)1522-3232    pin_general
# 7                    부산광역시 금정구 서동로 173 (서동)1522-3232    pin_general
# 8  부산광역시 남구 분포로 145 (용호동) 더블유스퀘어동 1019호,1020호,102...    pin_general
# 9                    부산광역시 남구 신선로 423 (용당동)1522-3232  pin_generalDT

# %%
# starbucks.groupby('stype').describe()
starbucks.info()

# %%
timestamp = datetime.now().strftime('%Y%m%d%H%M%S')
print(timestamp)
# Out:
# 20241230010252

# %%
timestamp = datetime.now().strftime('%Y%m%d%H%M%S')
csv_path = f'starbucks_{timestamp}.csv'
csv_file = starbucks.to_csv(csv_path, index=True)
print(f'변환 완료: {csv_path}')
path = f'./resultData/{csv_path}'

try:
    path = f'/user/hadoop/{csv_path}'
    hdfs = InsecureClient('http://namenode:9870', user='hadoop')
    hdfs.upload(path, csv_path)
    print('hdfs 업로드 완료')
except Exception as e:
    print(f'hdfs 업로드 실패 - {e}')
# Out:
# 변환 완료: starbucks_20241230010302.csv
# hdfs 업로드 완료

# %%
try:
    print(120 / 0 * 33)
except Exception as e:
    print(f'오류 발생 - {e}')

# %%
data = starbucks.copy()
coordinates = data[['lat', 'lon']].to_numpy()
coordinates
# Out:
# array([['35.2621786292157', '129.091325043351'],
#        ['35.2388135211636', '129.092985849499'],
#        ['35.224006', '129.08656'],
#        ['35.23212165114605', '129.0844959292725'],
#        ['35.23052180284867', '129.08869433543111'],
#        ['35.249819818853915', '129.09078227309334'],
#        ['35.246908383445785', '129.08873844189125'],
#        ['35.21463924851766', '129.10558442984572'],
#        ['35.1337011', '129.113324'],
#        ['35.12311959047579', '129.09901642703608'],
#        ['35.14631046844054', '129.0658885485103'],
#        ['35.13503615347691', '129.09309969594813'],
#        ['35.137345553736964', '129.10063775537583'],
#        ['35.144695123536415', '129.06430350788162'],
#        ['35.1299808', '129.0980971'],
#        ['35.1311', '129.1126'],
#        ['35.13609516236527', '129.09191736599408'],
#        ['35.11434481154264', '129.04030612857068'],
#        ['35.11612791103763', '129.04171604868281'],
#        ['35.11634794930394', '129.04069059547626'],
#        ['35.13879394894444', '129.06395425040046'],
#        ['35.15286800166649', '129.05944626017197'],
#        ['35.15524851626055', '129.0576381743508'],
#        ['35.170171720959104', '129.0692742371578'],
#        ['35.15495095970587', '129.03618733441533'],
#        ['35.1529820637631', '129.02259825927663'],
#        ['35.154364828346324', '129.06362887930075'],
#        ['35.1554897646539', '129.0589527478538'],
#        ['35.157919185437365', '129.0619520174245'],
#        ['35.154098', '129.061562'],
#        ['35.15789381388878', '129.0600009198993'],
#        ['35.16181113722542', '129.06201461279443'],
#        ['35.1516177133099', '129.06089873180213'],
#        ['35.157961', '129.05740949999995'],
#        ['35.15685353046891', '129.05798035954555'],
#        ['35.163831285849966', '129.0530396365257'],
#        ['35.1828193069829', '129.04748360769'],
#        ['35.14953868695743', '129.05888780315'],
#        ['35.15885783683483', '129.057495917852'],
#        ['35.210787', '129.008358'],
#        ['35.2336752802956', '129.013187668175'],
#        ['35.216972', '129.004611'],
#        ['35.1982412867577', '128.996280148597'],
#        ['35.213166', '129.039764'],
#        ['35.154847', '128.996302'],
#        ['35.150783485507844', '129.0098599874532'],
#        ['35.163891199333676', '128.9833401567374'],
#        ['35.1629709567761', '128.984586499721'],
#        ['35.176684552695', '128.976710446542'],
#        ['35.127533', '128.969588'],
#        ['35.16265589792603', '128.97897548212344'],
#        ['35.163833237506026', '128.9786199214018'],
#        ['35.04912735175173', '128.96356670482658'],
#        ['35.060973', '128.975257'],
#        ['35.115260', '128.959578'],
#        ['35.09838203957716', '128.9941945104235'],
#        ['35.106522', '128.966103'],
#        ['35.0849337', '128.9802207'],
#        ['35.198904092650125', '129.07893128206547'],
#        ['35.18797517098516', '129.0809085471317'],
#        ['35.18708216840511', '129.08318543518365'],
#        ['35.19568537974173', '129.07744953386472'],
#        ['35.184911403836246', '129.11250884445252'],
#        ['35.185394802963785', '129.08161110688536'],
#        ['35.18159', '129.07841'],
#        ['35.175745706845255', '129.08174091127475'],
#        ['35.1865001979024', '129.07157452462'],
#        ['35.093885', '129.065171'],
#        ['35.094678', '129.037184'],
#        ['35.100123', '129.031422'],
#        ['35.098378', '129.029716'],
#        ['35.102783', '129.028601'],
#        ['35.1050552', '129.0359604'],
#        ['35.098311', '129.035151'],
#        ['35.098937373325214', '129.0287430338355'],
#        ['35.2421513', '129.220117'],
#        ['35.184073', '129.210875'],
#        ['35.321336', '129.176983'],
#        ['35.25724296996289', '129.22513371734493'],
#        ['35.32270153066869', '129.23541462883986'],
#        ['35.19358296608474', '129.21421852069204'],
#        ['35.334446374142374', '129.17072655312796'],
#        ['35.3164532805935', '129.260928085016'],
#        ['35.1532166', '129.1246161'],
#        ['35.16573717329124', '129.1145750821663'],
#        ['35.147170', '129.110500'],
#        ['35.15317424344426', '129.1178487484164'],
#        ['35.177411', '129.107428'],
#        ['35.155026', '129.120851'],
#        ['35.14830649', '129.1141711'],
#        ['35.141257063803636', '129.106706345427'],
#        ['35.15400258151108', '129.12727354079507'],
#        ['35.17746', '129.117487'],
#        ['35.0934683', '128.9174322'],
#        ['35.1026237', '128.9294804'],
#        ['35.0978', '128.9203'],
#        ['35.084043', '128.903135'],
#        ['35.1128623326732', '128.879644210693'],
#        ['35.09724028810901', '128.90666213068852'],
#        ['35.20557928384287', '129.08011706501625'],
#        ['35.212443', '129.078378'],
#        ['35.1961928325401', '129.061604489178'],
#        ['35.1958595', '129.10695409999994'],
#        ['35.20719597598838', '129.07202514350354'],
#        ['35.19791171938551', '129.0605500953889'],
#        ['35.2213751233653', '129.085953323194'],
#        ['35.20292773253749', '129.0810293032682'],
#        ['35.220761664490546', '129.08272279990265'],
#        ['35.20560853458733', '129.0677604615084'],
#        ['35.077315', '129.017874'],
#        ['35.103629', '129.02022'],
#        ['35.112688', '129.016686'],
#        ['35.1195185', '129.0172766'],
#        ['35.158371', '129.153065'],
#        ['35.203889', '129.119336'],
#        ['35.178759', '129.122541'],
#        ['35.16314488870613', '129.159592828631'],
#        ['35.181271', '129.12405'],
#        ['35.16010998444482', '129.1621351429391'],
#        ['35.1678356', '129.13153920000002'],
#        ['35.1687027', '129.1297466'],
#        ['35.161561146872124', '129.17118262179758'],
#        ['35.174668', '129.126697'],
#        ['35.1807279', '129.20227690000001'],
#        ['35.16938036315796', '129.17635093623397'],
#        ['35.1596216193727', '129.159708147728'],
#        ['35.16884711', '129.1354444'],
#        ['35.16002278096324', '129.16600632968368'],
#        ['35.156657', '129.144091'],
#        ['35.1569194', '129.1434995'],
#        ['35.157925', '129.182307'],
#        ['35.166029', '129.167397'],
#        ['35.167027', '129.132829'],
#        ['35.171915887158804', '129.12851394978156'],
#        ['35.17137', '129.131112'],
#        ['35.15999407665911', '129.16861715737573'],
#        ['35.170306975015485', '129.1770642834487'],
#        ['35.1775937', '129.1755895'],
#        ['35.15977196666398', '129.16969758941596'],
#        ['35.167491', '129.1407913'],
#        ['35.16906348', '129.12906568'],
#        ['35.1671846', '129.1678855'],
#        ['35.1699363928397', '129.12834162026075'],
#        ['35.16006435481522', '129.1631763778927']], dtype=object)

# %%
place = data[['name']].to_numpy()
place
# Out:
# array([['금정남산동DT'],
#        ['금정구청DT'],
#        ['온천장역DT'],
#        ['부산대정문'],
#        ['부산대역'],
#        ['금정이마트'],
#        ['금정구서'],
#        ['부산서동'],
#        ['용호동W스퀘어'],
#        ['동명대DT'],
#        ['BIFC Mall'],
#        ['부산대연역'],
#        ['경성대'],
#        ['문현이마트'],
#        ['부산유엔공원'],
#        ['용호빌리브'],
#        ['부산대연못골'],
#        ['부산역라마다'],
#        ['부산역아스티'],
#        ['부산역'],
#        ['범일동일타워'],
#        ['서면중앙대로R'],
#        ['서면로R'],
#        ['양정역'],
#        ['동의대역'],
#        ['부산개금역'],
#        ['서면전포역'],
#        ['부산서면중앙로'],
#        ['서면서전로'],
#        ['부산서면'],
#        ['서면역'],
#        ['부전역'],
#        ['서면센트럴스퀘어'],
#        ['서면메디컬거리'],
#        ['서면중앙'],
#        ['서면트레이더스'],
#        ['초읍대공원'],
#        ['서면엠디엠타워'],
#        ['서면문화로'],
#        ['부산덕천역'],
#        ['부산화명역'],
#        ['화명강변DT'],
#        ['부산구남역DT'],
#        ['부산만덕DT'],
#        ['사상주례DT'],
#        ['동서대DT'],
#        ['사상역'],
#        ['부산사상로'],
#        ['삼락강변DT'],
#        ['사상엄궁DT'],
#        ['부산사상광장로'],
#        ['사상이마트'],
#        ['다대포비치'],
#        ['다대포DT'],
#        ['을숙도강변DT'],
#        ['부산괴정역'],
#        ['하단중앙'],
#        ['사하장림DT'],
#        ['부산교대역DT'],
#        ['연산시티타워'],
#        ['부산연산역'],
#        ['부산교대'],
#        ['연산트레이더스'],
#        ['연산교차로'],
#        ['부산시청'],
#        ['연제이마트'],
#        ['부산거제DT'],
#        ['영도청학DT'],
#        ['영도대교'],
#        ['부산광복로'],
#        ['자갈치역'],
#        ['국제시장'],
#        ['부산중앙역'],
#        ['남포동역'],
#        ['부산비프광장'],
#        ['기장역DT'],
#        ['동부산DT'],
#        ['부산정관'],
#        ['기장일광DT'],
#        ['부산P.아울렛'],
#        ['동부산테마파크'],
#        ['정관신도시DT'],
#        ['기장임랑원'],
#        ['광안수변공원'],
#        ['수영역'],
#        ['금련산역'],
#        ['광안비치'],
#        ['수영망미DT'],
#        ['광안리'],
#        ['남천'],
#        ['남천더샵'],
#        ['밀락더마켓'],
#        ['센텀수영DT'],
#        ['스타필드명지'],
#        ['명지강변DT'],
#        ['명지국제신도시'],
#        ['명지오션시티'],
#        ['강서녹산DT'],
#        ['명지퍼스트월드'],
#        ['동래역'],
#        ['명륜역'],
#        ['사직구장'],
#        ['부산안락DT'],
#        ['동래미남DT'],
#        ['부산사직'],
#        ['부산온천장역'],
#        ['부산동래'],
#        ['동래허심청'],
#        ['부산미남역'],
#        ['부산송도해수욕장'],
#        ['부민사거리'],
#        ['부산동대신역'],
#        ['동아대병원'],
#        ['해운대동백'],
#        ['수영강변DT'],
#        ['센텀파크'],
#        ['해운대역'],
#        ['부산재송DT'],
#        ['해운대'],
#        ['센텀로'],
#        ['센텀신세계B1'],
#        ['해운대달맞이DT'],
#        ['센텀그린타워'],
#        ['부산송정비치'],
#        ['장산역'],
#        ['하버타운'],
#        ['벡스코'],
#        ['팔레드시즈'],
#        ['제니스스퀘어'],
#        ['마린시티아이파크'],
#        ['해운대달맞이'],
#        ['해운대이마트'],
#        ['센텀드림월드'],
#        ['센텀KNN'],
#        ['월드마크센텀'],
#        ['엘시티'],
#        ['해운대NC'],
#        ['해운대좌동'],
#        ['해운대 엑스더스카이'],
#        ['부산성모안과병원'],
#        ['센텀신세계3F'],
#        ['해운대중동역'],
#        ['센텀몰1F'],
#        ['그랜드조선 부산']], dtype=object)

# %%
cn_lat, cn_lon = coordinates[4]
print(cn_lat, cn_lon)
m = folium.Map(location=[cn_lat, cn_lon], zoom_start=11)

for i, (lat, lon) in enumerate(coordinates):
    # print(lat, type(lat))
    folium.CircleMarker(
        location=[lat, lon],
        radius=10,
        color='blue',
        fill=True,
        fill_color='skyblue',
        fill_opacity=0.5,
        tooltip=place[i]
    ).add_to(m)
    # 라벨 추가 (Marker로 위치 조정)
    folium.Marker(
        location=[float(lat) + 0.001, float(lon)],  # 위도 약간 증가
        icon=folium.DivIcon(html=f'<div style="font-size: 9px; color: black; background-color: white; width:50px;white-space: nowrap; overflow: hidden;text-overflow: ellipsis;">{place[i]}</div>')
    ).add_to(m)
# 확인
m
# Out:
# 35.23052180284867 129.08869433543111
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4cea734e8bc5a4801bf904277b680b7b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4cea734e8bc5a4801bf904277b680b7b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4cea734e8bc5a4801bf904277b680b7b = L.map(
#                 &quot;map_4cea734e8bc5a4801bf904277b680b7b&quot;,
#                 {
#                     center: [35.23052180284867, 129.08869433543111],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eb277ae89f60f370ce94c14c140c621a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eb277ae89f60f370ce94c14c140c621a.addTo(map_4cea734e8bc5a4801bf904277b680b7b);
#
#
#             var circle_marker_648ca6340307c4a98099e3c1e66611d8 = L.circleMarker(
#                 [35.2621786292157, 129.091325043351],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;skyblue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4cea734e8bc5a4801bf904277b680b7b);
#
#
#             circle_marker_648ca6340307c4a98099e3c1e66611d8.bindTooltip(
#                 `&lt;div&gt;
#                      [&#x27;금정남산동DT&#x27;]
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_f7891f7bd4c3ebc9be5f95fe446e14c9 = L.marker(
#                 [35.263178629215695, 129.091325043351],
#                 {
# }
#             ).addTo(map_4cea734e8bc5a4801bf904277b680b7b);
#
#
#             var div_icon_a5762a6103f19680ebce12de09b7c280 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 9px; color: black; background-color: white; width:50px;white-space: nowrap; overflow: hidden;text-overflow: ellipsis;\&quot;\u003e[\u0027\uae08\uc815\ub0a8\uc0b0\ub3d9DT\u0027]\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_f7891f7bd4c3ebc9be5f95fe446e14c9.setIcon(div_icon_a5762a6103f19680ebce12de09b7c280);
#
#
#             var circle_marker_24681b3e5dadcbc6b0cfe54d81ce0ccb = L.circleMarker(
#                 [35.2388135211636, 129.092985849499],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;skyblue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4cea734e8bc5a4801bf904277b680b7b);
#
#
#             circle_marker_24681b3e5dadcbc6b0cfe54d81ce0ccb.bindTooltip(
#                 `&lt;div&gt;
#                      [&#x27;금정구청DT&#x27;]
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_4378b98c52c8491dd1d7db7c7b4a14d8 = L.marker(
#                 [35.2398135211636, 129.092985849499],
#                 {
# }
#             ).addTo(map_4cea734e8bc5a4801bf904277b680b7b);
#
#
#             var div_icon_afd56a848c4f8bf5851996aa786764f5 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 9px; color: black; background-color: white; width:50px;white-space: nowrap; overflow: hidden;text-overflow: ellipsis;\&quot;\u003e[\u0027\uae08\uc815\uad6c\uccadDT\u0027]\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_4378b98c52c8491dd1d7db7c7b4a14d8.setIcon(div_icon_afd56a848c4f8bf5851996aa786764f5);
#
#
#             var circle_marker_72dff786156336889a6c4f62da61041a = L.circleMarker(
#                 [35.224006, 129.08656],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;skyblue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4cea734e8bc5a4801bf904277b680b7b);
#
#
#             circle_marker_72dff786156336889a6c4f62da61041a.bindTooltip(
#                 `&lt;div&gt;
#                      [&#x27;온천장역DT&#x27
